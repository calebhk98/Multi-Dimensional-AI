# %% [markdown]
# # Training Metrics Analysis
#
# This notebook analyzes training metrics from Multi-Dimensional AI creature training runs.
#
# **Purpose:**
# - Load checkpoint and training logs
# - Visualize loss curves per modality
# - Analyze throughput and memory usage
# - Compare different training runs

# %%
import sys
sys.path.append('..')

import torch
import matplotlib.pyplot as plt
import pandas as pd
from pathlib import Path
import json

# %% [markdown]
# ## Load Training Logs

# %%
# Configure paths
LOG_DIR = Path('../logs')
CHECKPOINT_DIR = Path('../checkpoints')

# TODO: Load your training logs here
# Example: logs = pd.read_csv(LOG_DIR / 'training_log.csv')

print("Checkpoint directory:", CHECKPOINT_DIR)
print("Available checkpoints:", list(CHECKPOINT_DIR.glob('*.pt')))

# %% [markdown]
# ## Visualize Loss Curves

# %%
# Example visualization
fig, axes = plt.subplots(2, 2, figsize=(15, 10))

# TODO: Plot actual loss curves
# axes[0, 0].plot(steps, loss_internal_text, label='Internal Text')
# axes[0, 1].plot(steps, loss_external_text, label='External Text')
# axes[1, 0].plot(steps, loss_audio, label='Audio')
# axes[1, 1].plot(steps, loss_animation, label='Animation')

for ax in axes.flat:
	ax.set_xlabel('Training Steps')
	ax.set_ylabel('Loss')
	ax.legend()
	ax.grid(True)

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Analyze Per-Modality Loss

# %%
# Load checkpoint to inspect model state
# checkpoint = torch.load(CHECKPOINT_DIR / 'model_step_10000.pt')
# print(f"Training step: {checkpoint['step']}")
# print(f"Best validation loss: {checkpoint.get('best_val_loss', 'N/A')}")

# %% [markdown]
# ## Throughput Analysis

# %%
# TODO: Plot samples/sec over training
# plt.figure(figsize=(10, 6))
# plt.plot(steps, samples_per_sec)
# plt.xlabel('Training Steps')
# plt.ylabel('Samples/Second')
# plt.title('Training Throughput')
# plt.grid(True)
# plt.show()
